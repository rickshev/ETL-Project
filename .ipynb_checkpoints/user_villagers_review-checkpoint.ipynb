# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Store CSV into Dataframe

# %%
#read user review file and load it into datframe
file = "Resources/user_reviews.csv"
user_df = pd.read_csv(file)
user_df
# Out:
#       grade        user_name  \
# 0         4         mds27272
# 1         5         lolo2178
# 2         0         Roachant
# 3         0           Houndf
# 4         0     ProfessorFox
# ...     ...              ...
# 2994      1    TakezoShinmen
# 2995      1          Pikey17
# 2996      0        Lemmeadem
# 2997      2  TandemTester938
# 2998      4            DwerG
#
#                                                    text       date
# 0     My gf started playing before me. No option to ...  3/20/2020
# 1     While the game itself is great, really relaxin...  3/20/2020
# 2     My wife and I were looking forward to playing ...  3/20/2020
# 3     We need equal values and opportunities for all...  3/20/2020
# 4     BEWARE!  If you have multiple people in your h...  3/20/2020
# ...                                                 ...        ...
# 2994  1 Island for console limitation.I cannot play ...   5/3/2020
# 2995  Per giocare con figli o fidanzate, mogli o per...   5/3/2020
# 2996  One island per console is a pathetic limitatio...   5/3/2020
# 2997  Even though it seems like a great game with ma...   5/3/2020
# 2998  Game is fantastic.Nintendo deciding that you c...   5/3/2020
#
# [2999 rows x 4 columns]

# %%
#identifying incomplete rows
user_df.count()

##output for df count shows that there are no rows with null values
# Out:
# grade        2999
# user_name    2999
# text         2999
# date         2999
# dtype: int64

# %%
#Clean the user_review dataframe and keeping required columns
#drop the user_name column and any duplicate records
user_review_df=user_df[['grade', 'text', 'date']].copy()
user_review_df.drop_duplicates(inplace=True)
user_review_df
# Out:
#       grade                                               text       date
# 0         4  My gf started playing before me. No option to ...  3/20/2020
# 1         5  While the game itself is great, really relaxin...  3/20/2020
# 2         0  My wife and I were looking forward to playing ...  3/20/2020
# 3         0  We need equal values and opportunities for all...  3/20/2020
# 4         0  BEWARE!  If you have multiple people in your h...  3/20/2020
# ...     ...                                                ...        ...
# 2994      1  1 Island for console limitation.I cannot play ...   5/3/2020
# 2995      1  Per giocare con figli o fidanzate, mogli o per...   5/3/2020
# 2996      0  One island per console is a pathetic limitatio...   5/3/2020
# 2997      2  Even though it seems like a great game with ma...   5/3/2020
# 2998      4  Game is fantastic.Nintendo deciding that you c...   5/3/2020
#
# [2999 rows x 3 columns]

# %%
#read villagers file and load it into datframe
file = "Resources/villagers.csv"
villagers_df = pd.read_csv(file)
villagers_df
# Out:
#      row_n        id      name  gender    species birthday personality  \
# 0        2   admiral   Admiral    male       bird   27-Jan      cranky
# 1        3   agent-s   Agent S  female   squirrel    2-Jul       peppy
# 2        4     agnes     Agnes  female        pig   21-Apr        uchi
# 3        6        al        Al    male    gorilla   18-Oct        lazy
# 4        7   alfonso   Alfonso    male  alligator    9-Jun        lazy
# ..     ...       ...       ...     ...        ...      ...         ...
# 386    475    winnie    Winnie  female      horse   31-Jan       peppy
# 387    477  wolfgang  Wolfgang    male       wolf   25-Nov      cranky
# 388    480      yuka      Yuka  female      koala   20-Jul      snooty
# 389    481      zell      Zell    male       deer    7-Jun        smug
# 390    483    zucker    Zucker    male    octopus    8-Mar        lazy
#
#                 song    phrase            full_id  \
# 0         Steep Hill   aye aye   villager-admiral
# 1            DJ K.K.  sidekick   villager-agent-s
# 2         K.K. House   snuffle     villager-agnes
# 3         Steep Hill   Ayyeeee        villager-al
# 4        Forest Life  it'sa me   villager-alfonso
# ..               ...       ...                ...
# 386         My Place    hay-OK    villager-winnie
# 387        K.K. Song   snarrrl  villager-wolfgang
# 388     Soulful K.K.   tsk tsk      villager-yuka
# 389         K.K. D&B     pronk      villager-zell
# 390  Spring Blossoms     bloop    villager-zucker
#
#                                                    url
# 0    https://villagerdb.com/images/villagers/thumb/...
# 1    https://villagerdb.com/images/villagers/thumb/...
# 2    https://villagerdb.com/images/villagers/thumb/...
# 3    https://villagerdb.com/images/villagers/thumb/...
# 4    https://villagerdb.com/images/villagers/thumb/...
# ..                                                 ...
# 386  https://villagerdb.com/images/villagers/thumb/...
# 387  https://villagerdb.com/images/villagers/thumb/...
# 388  https://villagerdb.com/images/villagers/thumb/...
# 389  https://villagerdb.com/images/villagers/thumb/...
# 390  https://villagerdb.com/images/villagers/thumb/...
#
# [391 rows x 11 columns]

# %%
#identifying incomplete rows
villagers_df.count()
# Out:
# row_n          391
# id             390
# name           391
# gender         391
# species        391
# birthday       391
# personality    391
# song           380
# phrase         391
# full_id        391
# url            391
# dtype: int64

# %%
##above result shows that song and id columns have null values
#drop the rows with null values
villagers_df.dropna(inplace=True)
villagers_df.count()
# Out:
# row_n          379
# id             379
# name           379
# gender         379
# species        379
# birthday       379
# personality    379
# song           379
# phrase         379
# full_id        379
# url            379
# dtype: int64

# %%
#drop duplicates
villagers_df.drop_duplicates(inplace = True)
villagers_df.count()
# Out:
# row_n          379
# id             379
# name           379
# gender         379
# species        379
# birthday       379
# personality    379
# song           379
# phrase         379
# full_id        379
# url            379
# dtype: int64

# %%
villagers_df.head(10)
# Out:
#    row_n        id      name  gender    species birthday personality  \
# 0      2   admiral   Admiral    male       bird   27-Jan      cranky
# 1      3   agent-s   Agent S  female   squirrel    2-Jul       peppy
# 2      4     agnes     Agnes  female        pig   21-Apr        uchi
# 3      6        al        Al    male    gorilla   18-Oct        lazy
# 4      7   alfonso   Alfonso    male  alligator    9-Jun        lazy
# 5      8     alice     Alice  female      koala   19-Aug      normal
# 6      9      alli      Alli  female  alligator    8-Nov      snooty
# 7     10    amelia    Amelia  female      eagle   19-Nov      snooty
# 8     11  anabelle  Anabelle  female   anteater   16-Feb       peppy
# 9     13   anchovy   Anchovy    male       bird    4-Mar        lazy
#
#            song    phrase            full_id  \
# 0    Steep Hill   aye aye   villager-admiral
# 1       DJ K.K.  sidekick   villager-agent-s
# 2    K.K. House   snuffle     villager-agnes
# 3    Steep Hill   Ayyeeee        villager-al
# 4   Forest Life  it'sa me   villager-alfonso
# 5  Surfin' K.K.    guvnor     villager-alice
# 6  K.K. Chorale   graaagh      villager-alli
# 7   K.K. Condor    eaglet    villager-amelia
# 8    Aloha K.K.    snorty  villager-anabelle
# 9  K.K. Ragtime    chuurp   villager-anchovy
#
#                                                  url
# 0  https://villagerdb.com/images/villagers/thumb/...
# 1  https://villagerdb.com/images/villagers/thumb/...
# 2  https://villagerdb.com/images/villagers/thumb/...
# 3  https://villagerdb.com/images/villagers/thumb/...
# 4  https://villagerdb.com/images/villagers/thumb/...
# 5  https://villagerdb.com/images/villagers/thumb/...
# 6  https://villagerdb.com/images/villagers/thumb/...
# 7  https://villagerdb.com/images/villagers/thumb/...
# 8  https://villagerdb.com/images/villagers/thumb/...
# 9  https://villagerdb.com/images/villagers/thumb/...

# %%
#Clean dataframe
villagers_data_df=villagers_df[['name','gender','species', 'birthday', 'personality', 'song', 'phrase']].copy()
villagers_data_df
# Out:
#          name  gender    species birthday personality             song  \
# 0     Admiral    male       bird   27-Jan      cranky       Steep Hill
# 1     Agent S  female   squirrel    2-Jul       peppy          DJ K.K.
# 2       Agnes  female        pig   21-Apr        uchi       K.K. House
# 3          Al    male    gorilla   18-Oct        lazy       Steep Hill
# 4     Alfonso    male  alligator    9-Jun        lazy      Forest Life
# ..        ...     ...        ...      ...         ...              ...
# 386    Winnie  female      horse   31-Jan       peppy         My Place
# 387  Wolfgang    male       wolf   25-Nov      cranky        K.K. Song
# 388      Yuka  female      koala   20-Jul      snooty     Soulful K.K.
# 389      Zell    male       deer    7-Jun        smug         K.K. D&B
# 390    Zucker    male    octopus    8-Mar        lazy  Spring Blossoms
#
#        phrase
# 0     aye aye
# 1    sidekick
# 2     snuffle
# 3     Ayyeeee
# 4    it'sa me
# ..        ...
# 386    hay-OK
# 387   snarrrl
# 388   tsk tsk
# 389     pronk
# 390     bloop
#
# [379 rows x 7 columns]
