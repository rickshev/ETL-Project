# %% [markdown]
# # Scraping with Pandas

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.dialects.postgresql import insert
from sqlalchemy import table, column

# %% [markdown]
# ## Scraping from wiki sites

# %%
#We can use the `read_html` function in Pandas to automatically scrape any tabular data from a page.
#listing the urls for needed data
url1 = 'https://en.wikipedia.org/wiki/Animal_Crossing'
url2 = 'https://en.wikipedia.org/wiki/Characters_in_the_Animal_Crossing_series'
url3=  'https://animalcrossing.fandom.com/wiki/Category:Special_characters'

# %%
#scraping the data from wiki/Animal_Crossing
tables = pd.read_html(url1)
tables

# What we get in return is a list of dataframes for any tabular data that Pandas found stored in tables dataframe
# pulling required data from the second index in the , 'tables'list
Sales_summary = tables[2]
Sales_summary.columns = ['Name', 'Year.', 'Units_Sold', 'Critic_Score']

#We can slice off any of those dataframes that we want using normal indexing.
Sales_summary["Units_Sold"] = Sales_summary["Units_Sold"].str.split("[", n = 1, expand = True)[0]
Sales_summary["Critic_Score"] = Sales_summary["Critic_Score"].str.split("/", n = 1, expand = True)[0]
Sales_summary.head()
# Out:
#                             Name  Year. Units_Sold Critic_Score
# 0                Animal Crossing   2001       2.32           87
# 1    Animal Crossing: Wild World   2005      11.75           86
# 2     Animal Crossing: City Folk   2008       3.38           73
# 3      Animal Crossing: New Leaf   2012      12.45           88
# 4  Animal Crossing: New Horizons   2020      13.41           90

# %%
#scraping the data from 'https://en.wikipedia.org/wiki/Characters_in_the_Animal_Crossing_series'
tables1 = pd.read_html(url2)
tables1
# Out:
# [        Character                                Original Name  \
#  0         Alfonso                               アルベルト (Albert)
#  1          Apollo                                  アポロ (Aporo)
#  2          Blanca               あやしいねこ (lit. "Suspicious Cat")
#  3        Blathers                                 フータ (Hooter)
#  4          Booker  おまわりさんB・もんばんさんA (Policeman B; Gatekeeper A)
#  5           Cesar                                   アラン (Alan)
#  6            Chip                                うおまさ (Uomasa)
#  7          Copper  おまわりさんA・もんばんさんB (Policeman A; Gatekeeper B)
#  8          Cyrano                           さくらじま (Sakurajima)
#  9        Blathers                                 フータ (Hooter)
#  10    Don Resetti                         ラケットさん (Raketto-san)
#  11         Farley                                 ファーリー (Fārī)
#  12       Franklin                          フランクリン (Furankurin)
#  13         Gracie                                 グレース (Grace)
#  14       Gulliver                                ジョニー (Johnny)
#  15         Hopper                               ダルマン (Daruman)
#  16           Jack                            パンプキング (Pumpking)
#  17         Jingle                               ジングル (Jinguru)
#  18           Joan                              カブリバ (Kaburiba)
#  19    K.K. Slider                              とたけけ (Totakeke)
#  20         Kapp'n                                カッペイ (Kappei)
#  21        Katrina                              ハッケミィ (Hakkemī)
#  22          Mabel                                 きぬよ (Kinuyo)
#  23         Margie                                   サリー (Sarī)
#  24          Pelly                                 ぺりこ (Periko)
#  25           Pete                                  ぺりお (Pelio)
#  26        Phyllis                                 ぺりみ (Pelimi)
#  27         Porter                            えきいんさん (Ekiinsan)
#  28           Redd                            つねきち (Tsunekichi)
#  29    Mr. Resetti                         リセットさん (Risetto-san)
#  30          Rosie                          ブーケ (Būke, Bouquet)
#  31          Rover                  みしらぬネコ (lit. "Unknown Cat")
#  32          Sable                                  あさみ (Asami)
#  33        Saharah                                 ローラン (Rōran)
#  34  Timmy & Tommy           まめきち・つぶきち (Mamekichi & Tsubukichi)
#  35       Tom Nook                             たぬきち (Tanukichi)
#  36       Tortimer                              コトブキ (Kotobuki)
#  37        Wendell                               セイイチ (Seiichi)
#  38           Wisp                               ゆうたろう (Yūtarō)
#
#                 Species                                        Description
#  0            Alligator  A lazy villager. Also appears in the 2006 film...
#  1                Eagle  A grumpy villager. Also appears in the 2006 fi...
#  2                  Cat  A faceless cat who the player to draw their fa...
#  3                  Owl           Operates the museum. Brother to Celeste.
#  4        Dog (bulldog)  Works as a police officer in Animal Crossing a...
#  5              Gorilla  A grumpy villager. Also appears in the 2006 fi...
#  6               Beaver  Hosts the Fishing Tourney in all series titles...
#  7          Dog (Akita)  Works as a police officer in Animal Crossing a...
#  8             Anteater  A grumpy villager. Also appears in the 2006 fi...
#  9                  Owl           Operates the museum. Brother to Celeste.
#  10                Mole  Lectures the player if they reset their game. ...
#  11               Gnome       A spirit who lives inside the town fountain.
#  12              Turkey                        Hosts the Harvest Festival.
#  13             Giraffe                                A fashion designer.
#  14             Seagull  Appears as a marooned sailor Animal Crossing, ...
#  15             Penguin  A grumpy villager. Also appears in the 2006 fi...
#  16                   –    A pumpkin-headed character who hosts Halloween.
#  17            Reindeer                                     Hosts Toy Day.
#  18                Boar               Sells turnips on the "stalk market".
#  19  Dog (Jack Russell)                       A traveling musician and DJ.
#  20           Turtle[a]  A driver who has alternately operated a row bo...
#  21             Panther                                  A fortune teller.
#  22            Hedgehog  Co-owner of the Able Sisters tailor shop. Sist...
#  23            Elephant  A kind villager. Also appears in the 2006 film...
#  24             Pelican  Works the day shift at the post office in Anim...
#  25             Pelican                                    A mail carrier.
#  26             Pelican  Works the night shift at the post office in An...
#  27              Monkey                        Operates the train station.
#  28              Fox[b]  Operates a black market goods store. Also know...
#  29                Mole  Lectures the player if they reset their game. ...
#  30                 Cat  A peppy villager. Also appears in the 2006 fil...
#  31                 Cat  A cat who assists the player in setting up the...
#  32            Hedgehog  Co-owner of the Able Sisters tailor shop. Sist...
#  33               Camel                 A traveling rug and carpet seller.
#  34          Raccoon[c]          Twin apprentices and nephews to Tom Nook.
#  35          Raccoon[c]  A businessman who manages the town shop and th...
#  36            Tortoise  The mayor of the town. Retires to live on a tr...
#  37              Walrus                   A traveling artist and designer.
#  38               Ghost  A spirit who provides the player with rare items.  ,
#      Character        Original Name       Species  \
#  0    Brewster        マスター (Master)        Pigeon
#  1     Celeste           フーコ (Fuko)           Owl
#  2       Champ          さるお (Saruo)        Monkey
#  3  Dr. Shrunk        ししょー (Shishō)       Axolotl
#  4     Harriet   カットリーヌ (Kattorīnu)  Dog (poodle)
#  5     Kaitlin     おかあさん (Okaa-san)           Cat
#  6       Katie  まいこちゃん (Maiko-chan)           Cat
#  7        Lyle    ホンマさん (Honma-san)         Otter
#  8      Pascal      ラコスケ (Rakosuke)         Otter
#  9     Whitney        ビアンカ (Biance)          Wolf
#
#                                           Description
#  0                 Operates The Roost, a coffee shop.
#  1  Works at the museum observatory. Sister to Bla...
#  2  A jock villager. Also appears in the 2006 film...
#  3                         Teaches the player emotes.
#  4                Operates Shampoodle, a barber shop.
#  5                                   Mother to Katie.
#  6  A kitten who asks the player to reunite her wi...
#  7  A businessman who alternately works as an insu...
#  8                           A traveling philosopher.
#  9  A snooty villager. Also appears in the 2006 fi...  ,
#           Character          Original Name          Species  \
#  0         Frillard         きょしょー (Kyoshō)   Frilled lizard
#  1            Kicks          シャンク (Shanku)            Skunk
#  2            Label            ケイト (Keito)         Hedgehog
#  3            Lloid     ハニワくん (Haniwa-kun)           Gyroid
#  4              Nat  カメヤマさん (Kameyama-san)        Chameleon
#  5             Pavé       ベルリーナ (Berurīna)          Peacock
#  6          Phineas    パロンチーノ (Paronchīno)         Sea lion
#  7           Serena    めがみさま (Megami-sama)  Dog (Chihuahua)
#  8  Zipper T. Bunny     ぴょんたろう (Pyontarou)            Bunny
#
#                                           Description
#  0                         Teaches the player emotes.
#  1                    A shoeshiner and shoe salesman.
#  2  A fashion designer. Sister to Mable and Sable....
#  3  Operates the auction house in City Folk, and w...
#  4       Hosts the Bug-Off in City Folk and New Leaf.
#  5                                   Hosts Festivale.
#  6    Rewards the player with gifts and merit badges.
#  7      A goddess who lives inside the city fountain.
#  8                                   Hosts Bunny Day.  ,
#    Character   Original Name         Species  \
#  0     Cyrus    カイゾー (Kaizō)          Alpaca
#  1     Digby     ケント (Kento)  Dog (Shih Tzu)
#  2     Grams       ゲコ (Geko)       Turtle[a]
#  3    Harvey  パニエル (Panieru)   Dog (spaniel)
#  4  Isabelle    しずえ (Shizue)  Dog (Shih Tzu)
#  5      Leif     レイジ (Reiji)           Sloth
#  6     Leila       クク (Kuku)       Turtle[a]
#  7   Leilani      クーコ (Kūko)       Turtle[a]
#  8      Luna    ゆめみ (Yumemi)           Tapir
#  9     Reese       リサ (Risa)          Alpaca
#
#                                           Description
#  0  Works at Re-Tail, a refurbishment shop. Husban...
#  1  Works at the Happy Home Showcase. Twin brother...
#  2  Mother to Kapp'n, mother-in-law to Leilani, an...
#  3  A hippie. Operates the campground in New Leaf ...
#  4   A secretary and assistant. Twin sister to Digby.
#  5                      Operates the gardening store.
#  6  Daughter to Kapp'n and Leilani, and granddaugh...
#  7  Wife to Kapp'n, mother to Leilani, and daughte...
#  8                          Operates the Dream Suite.
#  9  Works at Re-Tail, a refurbishment shop. Wife t...  ,
#     Character    Original Name    Species  \
#  0       C.J.  ジャスティン (Justin)     Beaver
#  1  Daisy Mae         ウリ (Uri)       Boar
#  2      Flick       レックス (Rex)  Chameleon
#  3    Orville      モーリー (Mōrī)       Dodo
#  4    Raymond    ジャック (Jyakku)        Cat
#  5     Wilbur     ロドリー (Rodrī)       Dodo
#
#                                           Description
#  0  Hosts the Fishing Tourney. Son of Chip, and ro...
#  1              Sells turnips. Granddaughter of Joan.
#  2  Hosts the Bug-Off. Roommate and business partn...
#  3  Works as the receptionist for Dodo Airlines. B...
#  4  A smug villager. Noted by outlets as being esp...
#  5  Works as the pilot for Dodo Airlines. Brother ...  ,
#    Character      Original Name    Species  \
#  0        Ai                 あい      Human
#  1     Beppe   ピンちゃん (Pin-chan)  Blackbird
#  2     Carlo      グーさん (Gū-san)  Blackbird
#  3  Giovanni  キャンタロー (Kyantarō)  Blackbird
#  4    Lottie       タクミ (Takumi)      Otter
#  5        Yū                 ゆう      Human
#
#                                           Description
#  0  A female human villager. Protagonist of the 20...
#  1  Works at OK Motors. Introduced in Animal Cross...
#  2  Works at OK Motors. Introduced in Animal Cross...
#  3  Works at OK Motors. Introduced in Animal Cross...
#  4  Works at Nook's Homes. Niece to Lyle. Introduc...
#  5  A male human villager. Appears in the 2006 fil...  ,
#            Character  Forest  Crossing  Wild World  City Folk New Leaf  \
#  0            Blanca     NaN       NaN         NaN        NaN      NaN
#  1          Blathers     NaN       NaN         NaN        NaN      NaN
#  2            Booker     NaN       NaN         NaN        NaN      NaN
#  3          Brewster     NaN       NaN         NaN        NaN      NaN
#  4              C.J.     NaN       NaN         NaN        NaN      NaN
#  ..              ...     ...       ...         ...        ...      ...
#  58         Tortimer     NaN       NaN         NaN        NaN      NaN
#  59          Wendell     NaN       NaN         NaN        NaN      NaN
#  60           Wilbur     NaN       NaN         NaN        NaN      NaN
#  61             Wisp     NaN       NaN         NaN        NaN      DLC
#  62  Zipper T. Bunny     NaN       NaN         NaN        NaN      NaN
#
#     New Horizons
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  58          NaN
#  59          NaN
#  60          NaN
#  61          NaN
#  62          DLC
#
#  [63 rows x 7 columns],
#    vteAnimal Crossing                               vteAnimal Crossing.1
#  0              Games  Main series Animal Crossing Wild World City Fo...
#  1        Main series  Animal Crossing Wild World City Folk New Leaf ...
#  2    Spin-off titles  Plaza Happy Home Designer Amiibo Festival Pock...
#  3        Accessories                        e-Reader cards Amiibo cards
#  4         Characters          Isabelle Mr. Resetti Tom Nook K.K. Slider
#  5             People  Katsuya Eguchi Aya Kyogoku Hisashi Nogami Taka...
#  6        Other media                                               Film
#  7            Related  Nintendo Land Mario Kart 8 Super Smash Bros. f...,
#                   0                                                  1
#  0      Main series  Animal Crossing Wild World City Folk New Leaf ...
#  1  Spin-off titles  Plaza Happy Home Designer Amiibo Festival Pock...
#  2      Accessories                        e-Reader cards Amiibo cards]

# %%
#Extracting and storing the required data froms tables1
Animal_Forest = tables1[0]
Wild_World = tables1[1]
City_Folk = tables1[2]
New_Leaf = tables1[3]
New_Horizons = tables1[4]

#Naming the columns for each dataframe
Animal_Forest.columns = ['Character', 'Original_Name', 'Species', 'Description']
Wild_World.columns = ['Character', 'Orginal_Name.', 'Species', 'Description']
City_Folk.columns = ['Character', 'Orginal_Name.', 'Species', 'Description']
New_Leaf.columns = ['Character', 'Orginal_Name.', 'Species', 'Description']
New_Horizons.columns = ['Character', 'Orginal_Name.', 'Species', 'Description']

#extracting required columns from each dataframe
Animal_Forest['Name']='Animal_Forest'
Wild_World['Name']='Wild_World'
City_Folk['Name']='City_Folk'
New_Leaf['Name']='New_Leaf'
New_Horizons['Name']='New_Horizons'

#creating a new dataframe characters from the extracted columns
characters=pd.concat([Animal_Forest, Wild_World,City_Folk,New_Leaf,New_Horizons]).drop_duplicates()
characters= characters[['Character', 'Species', 'Description']]
characters
# Out:
#     Character        Species  \
# 0     Alfonso      Alligator
# 1      Apollo          Eagle
# 2      Blanca            Cat
# 3    Blathers            Owl
# 4      Booker  Dog (bulldog)
# ..        ...            ...
# 1   Daisy Mae           Boar
# 2       Flick      Chameleon
# 3     Orville           Dodo
# 4     Raymond            Cat
# 5      Wilbur           Dodo
#
#                                           Description
# 0   A lazy villager. Also appears in the 2006 film...
# 1   A grumpy villager. Also appears in the 2006 fi...
# 2   A faceless cat who the player to draw their fa...
# 3            Operates the museum. Brother to Celeste.
# 4   Works as a police officer in Animal Crossing a...
# ..                                                ...
# 1               Sells turnips. Granddaughter of Joan.
# 2   Hosts the Bug-Off. Roommate and business partn...
# 3   Works as the receptionist for Dodo Airlines. B...
# 4   A smug villager. Noted by outlets as being esp...
# 5   Works as the pilot for Dodo Airlines. Brother ...
#
# [73 rows x 3 columns]

# %%
#scraping the data from https://animalcrossing.fandom.com/wiki/Category:Special_characters
tables = pd.read_html(url3)
Special_Character = tables[0]

Special_Character.columns = ['Name', 'Image.', 'Species', 'Birthday','service']
Special_Character=Special_Character[['Name',  'Species', 'Birthday','service']]
Special_Character
# Out:
#                Name        Species        Birthday  \
# 0            Blanca            Cat    February 8th
# 1          Blathers            Owl  September 24th
# 2            Booker  Dog (Bulldog)      April 23rd
# 3          Brewster         Pigeon    October 15th
# 4              C.J.         Beaver       March 7th
# ..              ...            ...             ...
# 60         Tortimer       Tortoise        May 30th
# 61          Wendell         Walrus        May 30th
# 62           Wilbur           Dodo             NaN
# 63             Wisp         Spirit        May 30th
# 64  Zipper T. Bunny         Rabbit      March 11th
#
#                                               service
# 0   April Fools Day Host (NL) Town Visitor (AF, AC...
# 1             Museum Curator (AF, AC, WW, CF, NL, NH)
# 2   Police Station Officer (AC, NL) Gate Guard (WW...
# 3   The Roost Shopkeeper (WW, CF, NL, NH)  Gyroid ...
# 4                           Fishing Tourney Host (NH)
# ..                                                ...
# 60  Mayor (AF, AC, WW, CF) Animal Island Games Dir...
# 61   Town Visitor (AF, AC, WW, CF) Dream Visitor (NL)
# 62                           Dodo Airlines Pilot (NH)
# 63      Town Visitor (AF, AC, NH) Lamp Genie (CF, NL)
# 64                        Bunny Day Host (CF, NL, NH)
#
# [65 rows x 4 columns]

# %% [markdown]
# ### Sourcing the data from kaggle.com

# %%
#loading critic_review
csv_file = "Resources/critic.csv"
critic_df = pd.read_csv(csv_file)
critic_df.count()
# Out:
# grade          107
# publication    107
# text           107
# date           107
# dtype: int64

# %%
#checking the dataframe headers
critic_df
# Out:
#      grade       publication  \
# 0      100   Pocket Gamer UK
# 1      100            Forbes
# 2      100         Telegraph
# 3      100             VG247
# 4      100  Nintendo Insider
# ..     ...               ...
# 102     90      Impulsegamer
# 103     90        PLAY! Zine
# 104     95          GameGrin
# 105     90       NF Magazine
# 106     80             PCMag
#
#                                                   text       date
# 0    Animal Crossing; New Horizons, much like its p...  3/16/2020
# 1    Know that if you’re overwhelmed with the world...  3/16/2020
# 2    With a game this broad and lengthy, there’s mo...  3/16/2020
# 3    Animal Crossing: New Horizons is everything I ...  3/16/2020
# 4    Above all else, Animal Crossing: New Horizons ...  3/16/2020
# ..                                                 ...        ...
# 102  Animal Crossing New Horizons is pure fun and p...  4/16/2020
# 103  Animal Crossing: New Horizons is a definitive ...  4/17/2020
# 104  New Horizons is simply the best Animal Crossin...  4/22/2020
# 105  I can't wait to see what the future will hold....   5/1/2020
# 106  Animal Crossing: New Horizons brings the most ...   5/1/2020
#
# [107 rows x 4 columns]

# %%
#creating new dataframe with required columns
new_critic_df = critic_df[['grade', 'publication', 'date']].copy()
new_crtic_df = new_critic_df.drop_duplicates()
new_critic_df
# Out:
#      grade       publication       date
# 0      100   Pocket Gamer UK  3/16/2020
# 1      100            Forbes  3/16/2020
# 2      100         Telegraph  3/16/2020
# 3      100             VG247  3/16/2020
# 4      100  Nintendo Insider  3/16/2020
# ..     ...               ...        ...
# 102     90      Impulsegamer  4/16/2020
# 103     90        PLAY! Zine  4/17/2020
# 104     95          GameGrin  4/22/2020
# 105     90       NF Magazine   5/1/2020
# 106     80             PCMag   5/1/2020
#
# [107 rows x 3 columns]

# %%
#loading items
csv_file = "Resources/items.csv"
items_df = pd.read_csv(csv_file)
items_df.head()
len(items_df)

new_items_df = items_df[['num_id', 'name', 'category', 'sell_value', 'sell_currency', 'buy_value', 'buy_currency']].copy()
new_items_df.drop_duplicates(inplace=True)

new_items_df = new_items_df.dropna()
new_items_df
# Out:
#       num_id               name     category  sell_value sell_currency  \
# 0         12         3D Glasses  Accessories       122.0         bells
# 1         14              A Tee         Tops       140.0         bells
# 2         17      Abstract Wall    Wallpaper       390.0         bells
# 3         19    Academy Uniform      Dresses       520.0         bells
# 5         21  Accessories Stand    Furniture       375.0         bells
# ...      ...                ...          ...         ...           ...
# 4560    7425       Zigzag Shirt         Tops       240.0         bells
# 4561    7428    Zipper's Poster       Photos       250.0         bells
# 4562    7441               Zori        Shoes      1075.0         bells
# 4563    7442     Zucker's Photo       Photos        10.0         bells
# 4564    7443    Zucker's Poster       Photos       250.0         bells
#
#       buy_value buy_currency
# 0         490.0        bells
# 1         560.0        bells
# 2        1560.0        bells
# 3        2080.0        bells
# 5        1500.0        bells
# ...         ...          ...
# 4560      960.0        bells
# 4561     1000.0        bells
# 4562     4300.0        bells
# 4563       40.0        bells
# 4564     1000.0        bells
#
# [3417 rows x 7 columns]

# %%
#read user review file and load it into datframe
file = "Resources/user_reviews.csv"
user_df = pd.read_csv(file)
user_df

#identifying incomplete rows
user_df.count()

##output for df count shows that there are no rows with null values

#Clean the user_review dataframe and keeping required columns
#drop the user_name column and any duplicate records
user_review_df=user_df[['grade', 'text', 'date']].copy()
user_review_df.drop_duplicates(inplace=True)
user_review_df
# Out:
#       grade                                               text       date
# 0         4  My gf started playing before me. No option to ...  3/20/2020
# 1         5  While the game itself is great, really relaxin...  3/20/2020
# 2         0  My wife and I were looking forward to playing ...  3/20/2020
# 3         0  We need equal values and opportunities for all...  3/20/2020
# 4         0  BEWARE!  If you have multiple people in your h...  3/20/2020
# ...     ...                                                ...        ...
# 2994      1  1 Island for console limitation.I cannot play ...   5/3/2020
# 2995      1  Per giocare con figli o fidanzate, mogli o per...   5/3/2020
# 2996      0  One island per console is a pathetic limitatio...   5/3/2020
# 2997      2  Even though it seems like a great game with ma...   5/3/2020
# 2998      4  Game is fantastic.Nintendo deciding that you c...   5/3/2020
#
# [2999 rows x 3 columns]

# %%
#read villagers file and load it into datframe
file = "Resources/villagers.csv"
villagers_df = pd.read_csv(file)
villagers_df

#identifying incomplete rows
villagers_df.count()

##above result shows that song and id columns have null values
#drop the rows with null values
villagers_df.dropna(inplace=True)
villagers_df.count()

#drop duplicates
villagers_df.drop_duplicates(inplace = True)
villagers_df.count()

villagers_df.head(10)

#Clean dataframe
villagers_data_df=villagers_df[['name','gender','species', 'birthday', 'personality', 'song', 'phrase']].copy()
villagers_data_df
# Out:
#          name  gender    species birthday personality             song  \
# 0     Admiral    male       bird   27-Jan      cranky       Steep Hill
# 1     Agent S  female   squirrel    2-Jul       peppy          DJ K.K.
# 2       Agnes  female        pig   21-Apr        uchi       K.K. House
# 3          Al    male    gorilla   18-Oct        lazy       Steep Hill
# 4     Alfonso    male  alligator    9-Jun        lazy      Forest Life
# ..        ...     ...        ...      ...         ...              ...
# 386    Winnie  female      horse   31-Jan       peppy         My Place
# 387  Wolfgang    male       wolf   25-Nov      cranky        K.K. Song
# 388      Yuka  female      koala   20-Jul      snooty     Soulful K.K.
# 389      Zell    male       deer    7-Jun        smug         K.K. D&B
# 390    Zucker    male    octopus    8-Mar        lazy  Spring Blossoms
#
#        phrase
# 0     aye aye
# 1    sidekick
# 2     snuffle
# 3     Ayyeeee
# 4    it'sa me
# ..        ...
# 386    hay-OK
# 387   snarrrl
# 388   tsk tsk
# 389     pronk
# 390     bloop
#
# [379 rows x 7 columns]

# %%
#establish connecting with postgres database
rds_connection_string = "postgres:postgres@localhost:5432/animal_crossing_db"

engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#creating or appending tables as the case may be
Sales_summary.to_sql(name='sales_summary', con=engine, if_exists='append', index=False)

Special_Character.to_sql(name='special_character', con=engine, if_exists='append', index=False)

characters.to_sql(name='characters', con=engine, if_exists='append', index=False)

villagers_data_df.to_sql(name='villagers', con=engine, if_exists='append', index=False)

# %%
new_critic_df.to_sql(name='critic_review', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                     self.dialect.do_executemany(
# -> 1228                         cursor, statement, parameters, context
#    1229                     )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     856         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 857             cursor.executemany(statement, parameters)
#     858             return
#
# UniqueViolation: duplicate key value violates unique constraint "critic_review_pkey"
# DETAIL:  Key (publication)=(Pocket Gamer UK) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-16-0b20040ca110> in <module>
# ----> 1 new_critic_df.to_sql(name='critic_review', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     982             )
#     983         else:
# --> 984             return meth(self, multiparams, params)
#     985
#     986     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1101             distilled_params,
#    1102             compiled_sql,
# -> 1103             distilled_params,
#    1104         )
#    1105         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1286         except BaseException as e:
#    1287             self._handle_dbapi_exception(
# -> 1288                 e, statement, parameters, cursor, context
#    1289             )
#    1290
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1480             elif should_wrap:
#    1481                 util.raise_(
# -> 1482                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1483                 )
#    1484             else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1226                 if not evt_handled:
#    1227                     self.dialect.do_executemany(
# -> 1228                         cursor, statement, parameters, context
#    1229                     )
#    1230             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     855     def do_executemany(self, cursor, statement, parameters, context=None):
#     856         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 857             cursor.executemany(statement, parameters)
#     858             return
#     859
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "critic_review_pkey"
# DETAIL:  Key (publication)=(Pocket Gamer UK) already exists.
#
# [SQL: INSERT INTO critic_review (grade, publication, date) VALUES (%(grade)s, %(publication)s, %(date)s)]
# [parameters: ({'grade': 100, 'publication': 'Pocket Gamer UK', 'date': '3/16/2020'}, {'grade': 100, 'publication': 'Forbes', 'date': '3/16/2020'}, {'grade': 100, 'publication': 'Telegraph', 'date': '3/16/2020'}, {'grade': 100, 'publication': 'VG247', 'date': '3/16/2020'}, {'grade': 100, 'publication': 'Nintendo Insider', 'date': '3/16/2020'}, {'grade': 100, 'publication': 'Trusted Reviews', 'date': '3/16/2020'}, {'grade': 100, 'publication': 'VGC', 'date': '3/16/2020'}, {'grade': 100, 'publication': 'God is a Geek', 'date': '3/16/2020'}  ... displaying 10 of 107 total bound parameter sets ...  {'grade': 90, 'publication': 'NF Magazine', 'date': '5/1/2020'}, {'grade': 80, 'publication': 'PCMag', 'date': '5/1/2020'})]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
user_review_df.to_sql(name='user_reviews', con=engine, if_exists='append', index=False)

# %%
new_items_df.to_sql(name='items', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['critic_review',
#  'sales_summary',
#  'special_character',
#  'villagers',
#  'characters',
#  'user_reviews',
#  'items']

# %%
pd.read_sql_query('select * from sales_summary', con=engine).head(10)

pd.read_sql_query('select * from characters', con=engine).head()

pd.read_sql_query('select * from special_character', con=engine).head()
pd.read_sql_query('select * from villagers', con=engine).head()

# %%
pd.read_sql_query('select * from critic_review', con=engine)
# Out:
#      grade       publication       date
# 0      100   Pocket Gamer UK  3/16/2020
# 1      100            Forbes  3/16/2020
# 2      100         Telegraph  3/16/2020
# 3      100             VG247  3/16/2020
# 4      100  Nintendo Insider  3/16/2020
# ..     ...               ...        ...
# 102     90      Impulsegamer  4/16/2020
# 103     90        PLAY! Zine  4/17/2020
# 104     95          GameGrin  4/22/2020
# 105     90       NF Magazine   5/1/2020
# 106     80             PCMag   5/1/2020
#
# [107 rows x 3 columns]
